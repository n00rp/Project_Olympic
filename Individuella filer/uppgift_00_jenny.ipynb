# %%
import pandas as pd
import matplotlib.pyplot as plt

file = '../athlete_events.csv'

df = pd.read_csv(file)
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
# a) hur många länder som är med i datan?
country = len(df["NOC"].unique())
print(f" Antalet länder som är med i OS: {country}")
# Out:
#  Antalet länder som är med i OS: 230

# %%
# b) vilka länder är med? (förkortningarna räcker)
df["NOC"].unique()
# Out:
# array(['CHN', 'DEN', 'NED', 'USA', 'FIN', 'NOR', 'ROU', 'EST', 'FRA',
#        'MAR', 'ESP', 'EGY', 'IRI', 'BUL', 'ITA', 'CHA', 'AZE', 'SUD',
#        'RUS', 'ARG', 'CUB', 'BLR', 'GRE', 'CMR', 'TUR', 'CHI', 'MEX',
#        'URS', 'NCA', 'HUN', 'NGR', 'ALG', 'KUW', 'BRN', 'PAK', 'IRQ',
#        'UAR', 'LIB', 'QAT', 'MAS', 'GER', 'CAN', 'IRL', 'AUS', 'RSA',
#        'ERI', 'TAN', 'JOR', 'TUN', 'LBA', 'BEL', 'DJI', 'PLE', 'COM',
#        'KAZ', 'BRU', 'IND', 'KSA', 'SYR', 'MDV', 'ETH', 'UAE', 'YAR',
#        'INA', 'PHI', 'SGP', 'UZB', 'KGZ', 'TJK', 'EUN', 'JPN', 'CGO',
#        'SUI', 'BRA', 'FRG', 'GDR', 'MON', 'ISR', 'URU', 'SWE', 'ISV',
#        'SRI', 'ARM', 'CIV', 'KEN', 'BEN', 'UKR', 'GBR', 'GHA', 'SOM',
#        'LAT', 'NIG', 'MLI', 'AFG', 'POL', 'CRC', 'PAN', 'GEO', 'SLO',
#        'CRO', 'GUY', 'NZL', 'POR', 'PAR', 'ANG', 'VEN', 'COL', 'BAN',
#        'PER', 'ESA', 'PUR', 'UGA', 'HON', 'ECU', 'TKM', 'MRI', 'SEY',
# ...

# %%
# c) vilka sporter är med?
sport = df["Sport"].unique()
print(sport)
# Out:
# ['Basketball' 'Judo' 'Football' 'Tug-Of-War' 'Speed Skating'
#  'Cross Country Skiing' 'Athletics' 'Ice Hockey' 'Swimming' 'Badminton'
#  'Sailing' 'Biathlon' 'Gymnastics' 'Art Competitions' 'Alpine Skiing'
#  'Handball' 'Weightlifting' 'Wrestling' 'Luge' 'Water Polo' 'Hockey'
#  'Rowing' 'Bobsleigh' 'Fencing' 'Equestrianism' 'Shooting' 'Boxing'
#  'Taekwondo' 'Cycling' 'Diving' 'Canoeing' 'Tennis' 'Modern Pentathlon'
#  'Figure Skating' 'Golf' 'Softball' 'Archery' 'Volleyball'
#  'Synchronized Swimming' 'Table Tennis' 'Nordic Combined' 'Baseball'
#  'Rhythmic Gymnastics' 'Freestyle Skiing' 'Rugby Sevens' 'Trampolining'
#  'Beach Volleyball' 'Triathlon' 'Ski Jumping' 'Curling' 'Snowboarding'
#  'Rugby' 'Short Track Speed Skating' 'Skeleton' 'Lacrosse' 'Polo'
#  'Cricket' 'Racquets' 'Motorboating' 'Military Ski Patrol' 'Croquet'
#  'Jeu De Paume' 'Roque' 'Alpinism' 'Basque Pelota' 'Aeronautics']

# %%
# d) vilka medaljtyper finns det?
medalj = df["Medal"].unique()
print(medalj)
# Out:
# [nan 'Gold' 'Bronze' 'Silver']

# %%
# e) ta reda på statistik för åldern: medelvärde, median, min, max, standardavvikelse.
df["Age"].describe()
# Out:
# count    261642.000000
# mean         25.556898
# std           6.393561
# min          10.000000
# 25%          21.000000
# 50%          24.000000
# 75%          28.000000
# max          97.000000
# Name: Age, dtype: float64

# %%
# f) utforska datan vidare med egna frågor
GER = (df["NOC"] == "GER") & (df["Medal"] == "Gold")
GER = GER.sum()
print(f"Guld medaljer som Tyskland har tagit: {GER}")
# Out:
# Guld medaljer som Tyskland har tagit: 745

# %%
# g) diagram över könsfördelningen
df["Sex"].value_counts().plot(kind="bar", color=["Blue", "Pink"])
plt.title("Könsfördelning")
plt.xlabel("Kön")
plt.ylabel("Antal")
plt.show()

# %%
# h) diagram över topp 10 länder som tagit flest medaljer
top_10_countrys = df["Team"].value_counts().head(10)

top_10_countrys.plot(kind="bar", figsize=(10,6))
plt.title("Topp 10 länder som tagit flest medaljer")
plt.xlabel("Land")
plt.ylabel("Antal medaljer")
plt.show()

# %%
# i) plotta gärna fler saker som är intressant.
tyskland_medaljer = df[(df["NOC"] == "GER") & (df["Medal"] != "NA")]

tyskland_medaljer["Sport"].value_counts().plot(kind="bar", figsize=(10,6))
plt.xlabel("Sport")
plt.ylabel("Antal medaljer")
plt.title("Tysklands medaljer per sport")

plt.tight_layout()
plt.show()

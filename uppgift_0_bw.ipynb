# %%
# a), b)

import pandas as pd

df=pd.read_csv("athlete_events.csv")

print(df["NOC"].unique())
len(df["NOC"].unique())

# Svar: 230 olika länder
# Out:
# ['CHN' 'DEN' 'NED' 'USA' 'FIN' 'NOR' 'ROU' 'EST' 'FRA' 'MAR' 'ESP' 'EGY'
#  'IRI' 'BUL' 'ITA' 'CHA' 'AZE' 'SUD' 'RUS' 'ARG' 'CUB' 'BLR' 'GRE' 'CMR'
#  'TUR' 'CHI' 'MEX' 'URS' 'NCA' 'HUN' 'NGR' 'ALG' 'KUW' 'BRN' 'PAK' 'IRQ'
#  'UAR' 'LIB' 'QAT' 'MAS' 'GER' 'CAN' 'IRL' 'AUS' 'RSA' 'ERI' 'TAN' 'JOR'
#  'TUN' 'LBA' 'BEL' 'DJI' 'PLE' 'COM' 'KAZ' 'BRU' 'IND' 'KSA' 'SYR' 'MDV'
#  'ETH' 'UAE' 'YAR' 'INA' 'PHI' 'SGP' 'UZB' 'KGZ' 'TJK' 'EUN' 'JPN' 'CGO'
#  'SUI' 'BRA' 'FRG' 'GDR' 'MON' 'ISR' 'URU' 'SWE' 'ISV' 'SRI' 'ARM' 'CIV'
#  'KEN' 'BEN' 'UKR' 'GBR' 'GHA' 'SOM' 'LAT' 'NIG' 'MLI' 'AFG' 'POL' 'CRC'
#  'PAN' 'GEO' 'SLO' 'CRO' 'GUY' 'NZL' 'POR' 'PAR' 'ANG' 'VEN' 'COL' 'BAN'
#  'PER' 'ESA' 'PUR' 'UGA' 'HON' 'ECU' 'TKM' 'MRI' 'SEY' 'TCH' 'LUX' 'MTN'
#  'CZE' 'SKN' 'TTO' 'DOM' 'VIN' 'JAM' 'LBR' 'SUR' 'NEP' 'MGL' 'AUT' 'PLW'
#  'LTU' 'TOG' 'NAM' 'AHO' 'ISL' 'ASA' 'SAM' 'RWA' 'DMA' 'HAI' 'MLT' 'CYP'
#  'GUI' 'BIZ' 'YMD' 'KOR' 'THA' 'BER' 'ANZ' 'SCG' 'SLE' 'PNG' 'YEM' 'IOA'
#  'OMA' 'FIJ' 'VAN' 'MDA' 'YUG' 'BAH' 'GUA' 'SRB' 'IVB' 'MOZ' 'CAF' 'MAD'
#  'MAL' 'BIH' 'GUM' 'CAY' 'SVK' 'BAR' 'GBS' 'TLS' 'COD' 'GAB' 'SMR' 'LAO'
#  'BOT' 'ROT' 'CAM' 'PRK' 'SOL' 'SEN' 'CPV' 'CRT' 'GEQ' 'BOL' 'SAA' 'AND'
#  'ANT' 'ZIM' 'GRN' 'HKG' 'LCA' 'FSM' 'MYA' 'MAW' 'ZAM' 'RHO' 'TPE' 'STP'
#  'MKD' 'BOH' 'TGA' 'LIE' 'MNE' 'GAM' 'COK' 'ALB' 'WIF' 'SWZ' 'BUR' 'NBO'
#  'BDI' 'ARU' 'NRU' 'VNM' 'VIE' 'BHU' 'MHL' 'KIR' 'UNK' 'TUV' 'NFL' 'KOS'
#  'SSD' 'LES']
# 230

# %%
# c)

print(df["Sport"].unique())
# Out:
# ['Basketball' 'Judo' 'Football' 'Tug-Of-War' 'Speed Skating'
#  'Cross Country Skiing' 'Athletics' 'Ice Hockey' 'Swimming' 'Badminton'
#  'Sailing' 'Biathlon' 'Gymnastics' 'Art Competitions' 'Alpine Skiing'
#  'Handball' 'Weightlifting' 'Wrestling' 'Luge' 'Water Polo' 'Hockey'
#  'Rowing' 'Bobsleigh' 'Fencing' 'Equestrianism' 'Shooting' 'Boxing'
#  'Taekwondo' 'Cycling' 'Diving' 'Canoeing' 'Tennis' 'Modern Pentathlon'
#  'Figure Skating' 'Golf' 'Softball' 'Archery' 'Volleyball'
#  'Synchronized Swimming' 'Table Tennis' 'Nordic Combined' 'Baseball'
#  'Rhythmic Gymnastics' 'Freestyle Skiing' 'Rugby Sevens' 'Trampolining'
#  'Beach Volleyball' 'Triathlon' 'Ski Jumping' 'Curling' 'Snowboarding'
#  'Rugby' 'Short Track Speed Skating' 'Skeleton' 'Lacrosse' 'Polo'
#  'Cricket' 'Racquets' 'Motorboating' 'Military Ski Patrol' 'Croquet'
#  'Jeu De Paume' 'Roque' 'Alpinism' 'Basque Pelota' 'Aeronautics']

# %%
# d)

print(df["Medal"].unique())
# Out:
# [nan 'Gold' 'Bronze' 'Silver']

# %%
# e)

df["Age"].agg(["mean", "std", "min", "max", "median"])
# Out:
# mean      25.556898
# std        6.393561
# min       10.000000
# max       97.000000
# median    24.000000
# Name: Age, dtype: float64

# %%
df.loc[df["Age"]>75]
# Out:
#             ID                            Name Sex   Age  Height  Weight  \
# 9371      5146           George Denholm Armour   M  84.0     NaN     NaN
# 56599    28993                    Albin Dbrich   M  76.0     NaN     NaN
# 56600    28993                    Albin Dbrich   M  76.0     NaN     NaN
# 56601    28993                    Albin Dbrich   M  76.0     NaN     NaN
# 60861    31173      Thomas Cowperthwait Eakins   M  88.0     NaN     NaN
# 60862    31173      Thomas Cowperthwait Eakins   M  88.0     NaN     NaN
# 60863    31173      Thomas Cowperthwait Eakins   M  88.0     NaN     NaN
# 62839    32215            George Alfred Elcock   M  76.0     NaN     NaN
# 98118    49663                   Winslow Homer   M  96.0     NaN     NaN
# 133533   67219                 Sir John Lavery   M  76.0     NaN     NaN
# 133534   67219                 Sir John Lavery   M  76.0     NaN     NaN
# 138812   69729                  Max Liebermann   M  80.0     NaN     NaN
# 138813   69729                  Max Liebermann   M  80.0     NaN     NaN
# 138814   69729                  Max Liebermann   M  80.0     NaN     NaN
# 154855   77710            Robert Tait McKenzie   M  81.0     NaN     NaN
# 170798   85838  William Newzam Prior Nicholson   M  76.0     NaN     NaN
# 170993   85936           Charles Henry Niehaus   M  77.0     NaN     NaN
# 170994   85936           Charles Henry Niehaus   M  77.0     NaN     NaN
# 236912  118789                    Louis Tauzin   M  81.0     NaN     NaN
# 257054  128719          John Quincy Adams Ward   M  97.0     NaN     NaN
#
#                  Team  NOC        Games  Year  Season         City  \
# 9371    Great Britain  GBR  1948 Summer  1948  Summer       London
# 56599         Austria  AUT  1948 Summer  1948  Summer       London
# 56600         Austria  AUT  1948 Summer  1948  Summer       London
# 56601         Austria  AUT  1948 Summer  1948  Summer       London
# 60861   United States  USA  1932 Summer  1932  Summer  Los Angeles
# 60862   United States  USA  1932 Summer  1932  Summer  Los Angeles
# 60863   United States  USA  1932 Summer  1932  Summer  Los Angeles
# 62839   Great Britain  GBR  1932 Summer  1932  Summer  Los Angeles
# 98118   United States  USA  1932 Summer  1932  Summer  Los Angeles
# 133533  Great Britain  GBR  1932 Summer  1932  Summer  Los Angeles
# 133534  Great Britain  GBR  1932 Summer  1932  Summer  Los Angeles
# 138812        Germany  GER  1928 Summer  1928  Summer    Amsterdam
# 138813        Germany  GER  1928 Summer  1928  Summer    Amsterdam
# 138814        Germany  GER  1928 Summer  1928  Summer    Amsterdam
# 154855         Canada  CAN  1948 Summer  1948  Summer       London
# 170798  Great Britain  GBR  1948 Summer  1948  Summer       London
# 170993  United States  USA  1932 Summer  1932  Summer  Los Angeles
# 170994  United States  USA  1932 Summer  1932  Summer  Los Angeles
# 236912         France  FRA  1924 Summer  1924  Summer        Paris
# 257054  United States  USA  1928 Summer  1928  Summer    Amsterdam
#
#                    Sport                                              Event  \
# 9371    Art Competitions     Art Competitions Mixed Painting, Unknown Event
# 56599   Art Competitions  Art Competitions Mixed Sculpturing, Unknown Event
# 56600   Art Competitions  Art Competitions Mixed Sculpturing, Unknown Event
# 56601   Art Competitions  Art Competitions Mixed Sculpturing, Unknown Event
# 60861   Art Competitions     Art Competitions Mixed Painting, Unknown Event
# 60862   Art Competitions     Art Competitions Mixed Painting, Unknown Event
# 60863   Art Competitions     Art Competitions Mixed Painting, Unknown Event
# 62839   Art Competitions     Art Competitions Mixed Painting, Unknown Event
# 98118   Art Competitions     Art Competitions Mixed Painting, Unknown Event
# 133533  Art Competitions     Art Competitions Mixed Painting, Unknown Event
# 133534  Art Competitions     Art Competitions Mixed Painting, Unknown Event
# 138812  Art Competitions      Art Competitions Mixed Painting, Graphic Arts
# 138813  Art Competitions      Art Competitions Mixed Painting, Graphic Arts
# 138814  Art Competitions      Art Competitions Mixed Painting, Graphic Arts
# 154855  Art Competitions  Art Competitions Mixed Sculpturing, Unknown Event
# 170798  Art Competitions     Art Competitions Mixed Painting, Unknown Event
# 170993  Art Competitions  Art Competitions Mixed Sculpturing, Unknown Event
# 170994  Art Competitions  Art Competitions Mixed Sculpturing, Unknown Event
# 236912  Art Competitions                 Art Competitions Mixed Sculpturing
# 257054  Art Competitions        Art Competitions Mixed Sculpturing, Statues
#
#        Medal
# 9371     NaN
# 56599    NaN
# 56600    NaN
# 56601    NaN
# 60861    NaN
# 60862    NaN
# 60863    NaN
# 62839    NaN
# 98118    NaN
# 133533   NaN
# 133534   NaN
# 138812   NaN
# 138813   NaN
# 138814   NaN
# 154855   NaN
# 170798   NaN
# 170993   NaN
# 170994   NaN
# 236912   NaN
# 257054   NaN
